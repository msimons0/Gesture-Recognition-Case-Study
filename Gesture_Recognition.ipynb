# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started. Once you have completed the code you can download the notebook for making a submission.

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow import keras
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %% [markdown]
# **data path: /home/datasets/Project_data**

# %%
train_doc = np.random.permutation(open('/home/datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/home/datasets/Project_data/val.csv').readlines())
batch_size = 8 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 100
image_width = 100
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int) #create a list of image numbers you want to use for a particular video

# %%
from skimage.io import imread
from skimage.transform import resize

def resize_crop_image(image):
    if image.shape[0] > 120 and image.shape[1] > 120:
        image = resize(image, (120, 120))
        
    height = image.shape[0]
    width = image.shape[1]
    height_center = height//2
    width_center = width//2
    image = image[(height_center-60):(height_center+70), (width_center-50):(width_center+70)]
    image = resize(image,(image_height, image_width))
    return image

# %% [markdown]
# Let's test the function `resize_crop_image` by writing a test function

# %%
from matplotlib import pyplot as plt

def show_resize_crop_image(paths):

    for index, path in enumerate(paths):
        plt.figure(figsize=(20,20))
            
        plt.subplot(5, 2, index*2+1)
        image = resize_crop_image(imread(path))
        plt.imshow(image)
        plt.title('Modified')
        
        plt.subplot(5, 2, index*2+2)
        plt.imshow(imread(path))
        plt.title('Original')
                
    plt.show()

# %% [markdown]
# Calling the test function

# %%
paths = ["/home/datasets/Project_data/train/WIN_20180907_15_53_00_Pro_Thumbs Down_new/WIN_20180907_15_53_00_Pro_00001.png",
        "/home/datasets/Project_data/train/WIN_20180907_15_56_38_Pro_Right Swipe_new/WIN_20180907_15_56_38_Pro_00013.png",
        "/home/datasets/Project_data/train/WIN_20180925_17_22_32_Pro_Right_Swipe_new/WIN_20180925_17_22_32_Pro_00009.png",
        "/home/datasets/Project_data/train/WIN_20180907_15_53_12_Pro_Thumbs Up_new/WIN_20180907_15_53_12_Pro_00011.png"]

show_resize_crop_image(paths)

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size, len(img_idx), image_height, image_width, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, gestures)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    image = resize_crop_image(image)
                                         
                    batch_data[folder,idx,:,:,0] = image[:,:,0] #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = image[:,:,1] #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = image[:,:,2] #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size * num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            
            for batch in range(batch_size): # we iterate over the number of batches
                batch_data = np.zeros((batch_size, len(img_idx), image_height, image_width, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
                batch_labels = np.zeros((batch_size, gestures)) # batch_labels is the one hot representation of the output
                for folder in range(batch_size): # iterate over the batch_size
                    imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                    for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                        image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                        #crop the images and resize them. Note that the images are of 2 different shape 
                        #and the conv3D will throw error if the inputs in a batch have different shapes
                        image = resize_crop_image(image)
                                         
                        batch_data[folder,idx,:,:,0] = image[:,:,0] #normalise and feed in the image
                        batch_data[folder,idx,:,:,1] = image[:,:,1] #normalise and feed in the image
                        batch_data[folder,idx,:,:,2] = image[:,:,2] #normalise and feed in the image
                    
                    batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
                yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/home/datasets/Project_data/train'
val_path = '/home/datasets/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 25

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ### Experiment 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation, Conv3D, MaxPooling3D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import optimizers

#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.7, nesterov=True) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 15, 100, 100, 8)   656
# _________________________________________________________________
# batch_normalization (BatchNo (None, 15, 100, 100, 8)   32
# _________________________________________________________________
# activation (Activation)      (None, 15, 100, 100, 8)   0
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 7, 50, 50, 8)      0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 7, 50, 50, 16)     3472
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 50, 50, 16)     64
# _________________________________________________________________
# activation_1 (Activation)    (None, 7, 50, 50, 16)     0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 3, 25, 25, 16)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 3, 25, 25, 32)     13856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 25, 25, 32)     128
# _________________________________________________________________
# activation_2 (Activation)    (None, 3, 25, 25, 32)     0
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 1, 12, 12, 32)     0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                294976
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 317,669
# Trainable params: 317,557
# Non-trainable params: 112
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit` method to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 8
# Epoch 1/25
# 83/83 [==============================] - ETA: 0s - loss: 1.7717 - categorical_accuracy: 0.2051Source path =  /home/datasets/Project_data/val ; batch size = 8
#
# Epoch 00001: val_loss improved from inf to 1.59229, saving model to model_init_2021-06-2808_36_21.106173/model-00001-1.77166-0.20513-1.59229-0.27000.h5
# 83/83 [==============================] - 82s 993ms/step - loss: 1.7717 - categorical_accuracy: 0.2051 - val_loss: 1.5923 - val_categorical_accuracy: 0.2700
# Epoch 2/25
# 83/83 [==============================] - ETA: 0s - loss: 1.5893 - categorical_accuracy: 0.2478
# Epoch 00002: val_loss improved from 1.59229 to 1.52560, saving model to model_init_2021-06-2808_36_21.106173/model-00002-1.58934-0.24785-1.52560-0.26923.h5
# 83/83 [==============================] - 68s 819ms/step - loss: 1.5893 - categorical_accuracy: 0.2478 - val_loss: 1.5256 - val_categorical_accuracy: 0.2692
# Epoch 3/25
# 83/83 [==============================] - ETA: 0s - loss: 1.5587 - categorical_accuracy: 0.3073
# Epoch 00003: val_loss did not improve from 1.52560
# 83/83 [==============================] - 53s 636ms/step - loss: 1.5587 - categorical_accuracy: 0.3073 - val_loss: 1.5332 - val_categorical_accuracy: 0.3654
# Epoch 4/25
# 83/83 [==============================] - ETA: 0s - loss: 1.5725 - categorical_accuracy: 0.2455
# Epoch 00004: val_loss improved from 1.52560 to 1.44542, saving model to model_init_2021-06-2808_36_21.106173/model-00004-1.57252-0.24552-1.44542-0.44231.h5
# 83/83 [==============================] - 53s 636ms/step - loss: 1.5725 - categorical_accuracy: 0.2455 - val_loss: 1.4454 - val_categorical_accuracy: 0.4423
# Epoch 5/25
# 83/83 [==============================] - ETA: 0s - loss: 1.5197 - categorical_accuracy: 0.3173
# Epoch 00005: val_loss did not improve from 1.44542
# 83/83 [==============================] - 35s 420ms/step - loss: 1.5197 - categorical_accuracy: 0.3173 - val_loss: 1.4564 - val_categorical_accuracy: 0.4231
# Epoch 6/25
# 83/83 [==============================] - ETA: 0s - loss: 1.6095 - categorical_accuracy: 0.2129
# Epoch 00006: val_loss improved from 1.44542 to 1.43427, saving model to model_init_2021-06-2808_36_21.106173/model-00006-1.60953-0.21285-1.43427-0.44231.h5
# 83/83 [==============================] - 33s 398ms/step - loss: 1.6095 - categorical_accuracy: 0.2129 - val_loss: 1.4343 - val_categorical_accuracy: 0.4423
# Epoch 7/25
# 83/83 [==============================] - ETA: 0s - loss: 1.
25
# 83/83 [==============================] - ETA: 0s - loss: 1.2146 - categorical_accuracy: 0.4498
# Epoch 00025: val_loss improved from 1.03172 to 1.02974, saving model to model_init_2021-06-2808_36_21.106173/model-00025-1.21464-0.44980-1.02974-0.65385.h5
# 83/83 [==============================] - 34s 415ms/step - loss: 1.2146 - categorical_accuracy: 0.4498 - val_loss: 1.0297 - val_categorical_accuracy: 0.6538

# %%
from IPython.display import Markdown, display

def plot_history(history):
    display(Markdown("**Training Accuracy:** " + str(round(history.history['categorical_accuracy'][num_epochs-1], 2)) + "%"))
    display(Markdown("**Validation Accuracy:** " + str(round(history.history['val_categorical_accuracy'][num_epochs-1], 2)) + "%"))
    
    #print("Training Accuracy:" + history.history['categorical_accuracy'][num_epochs-1])
    #print("Validation Accuracy:" + history.history['val_categorical_accuracy'][num_epochs-1])

    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(num_epochs)

    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

plot_history(history)
# Out:
# **Training Accuracy:** 0.45%
# **Validation Accuracy:** 0.65%

# %% [markdown]
# From the graph we can see that the model is performing better on the validation data than on the training data. This indicates that the model is too simple and has lesser that required training parameters

# %% [markdown]
# ### Experiment 2

# %% [markdown]
# Reducing the size of the image from 100 to 50

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)

num_epochs=25

show_resize_crop_image(paths)

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

# %% [markdown]
# Compiling the model and printing the summary of the model

# %%
optimiser = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.7, nesterov=True) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_3 (Conv3D)            (None, 15, 50, 50, 8)     656
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 15, 50, 50, 8)     32
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 50, 50, 8)     0
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 7, 25, 25, 8)      0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 7, 25, 25, 16)     3472
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 25, 25, 16)     64
# _________________________________________________________________
# activation_4 (Activation)    (None, 7, 25, 25, 16)     0
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 3, 12, 12, 16)     0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 3, 12, 12, 32)     13856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 12, 12, 32)     128
# _________________________________________________________________
# activation_5 (Activation)    (None, 3, 12, 12, 32)     0
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 1, 6, 6, 32)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                73792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %% [markdown]
# Creating the generators

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_exp2_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Fit the model and save the model parameters

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 8
# Epoch 1/25
# 83/83 [==============================] - ETA: 0s - loss: 1.9441 - categorical_accuracy: 0.2112Source path =  /home/datasets/Project_data/val ; batch size = 8
#
# Epoch 00001: val_loss improved from inf to 1.70630, saving model to model_exp2_2021-06-2808_36_21.106173/model-00001-1.94413-0.21116-1.70630-0.18000.h5
# 83/83 [==============================] - 76s 915ms/step - loss: 1.9441 - categorical_accuracy: 0.2112 - val_loss: 1.7063 - val_categorical_accuracy: 0.1800
# Epoch 2/25
# 83/83 [==============================] - ETA: 0s - loss: 1.5955 - categorical_accuracy: 0.2444
# Epoch 00002: val_loss improved from 1.70630 to 1.48438, saving model to model_exp2_2021-06-2808_36_21.106173/model-00002-1.59549-0.24441-1.48438-0.36538.h5
# 83/83 [==============================] - 62s 752ms/step - loss: 1.5955 - categorical_accuracy: 0.2444 - val_loss: 1.4844 - val_categorical_accuracy: 0.3654
# Epoch 3/25
# 83/83 [==============================] - ETA: 0s - loss: 1.
25
# 83/83 [==============================] - ETA: 0s - loss: 1.3785 - categorical_accuracy: 0.3855
# Epoch 00024: val_loss did not improve from 1.14992
# 83/83 [==============================] - 34s 404ms/step - loss: 1.3785 - categorical_accuracy: 0.3855 - val_loss: 1.2531 - val_categorical_accuracy: 0.5192
# Epoch 25/25
# 83/83 [==============================] - ETA: 0s - loss: 1.3170 - categorical_accuracy: 0.4177
# Epoch 00025: val_loss did not improve from 1.14992
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 83/83 [==============================] - 32s 391ms/step - loss: 1.3170 - categorical_accuracy: 0.4177 - val_loss: 1.2064 - val_categorical_accuracy: 0.5769

# %% [markdown]
# Evaluate the performance of this model

# %%
plot_history(history)
# Out:
# **Training Accuracy:** 0.42%
# **Validation Accuracy:** 0.58%

# %% [markdown]
# <b>Conclusion:</b> Scaling to smaller images work better

# %% [markdown]
# ## Experiment 3

# %% [markdown]
# Reducing the size of the image from 50 to 25

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 25
image_width = 25
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)

num_epochs=25

show_resize_crop_image(paths)

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

# %% [markdown]
# Compiling the model and printing the summary of the model

# %%
optimiser = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.7, nesterov=True) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_6 (Conv3D)            (None, 15, 25, 25, 8)     656
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 15, 25, 25, 8)     32
# _________________________________________________________________
# activation_6 (Activation)    (None, 15, 25, 25, 8)     0
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 7, 12, 12, 8)      0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 7, 12, 12, 16)     3472
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 7, 12, 12, 16)     64
# _________________________________________________________________
# activation_7 (Activation)    (None, 7, 12, 12, 16)     0
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 3, 6, 6, 16)       0
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 6, 6, 32)       13856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 6, 6, 32)       128
# _________________________________________________________________
# activation_8 (Activation)    (None, 3, 6, 6, 32)       0
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 1, 3, 3, 32)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 288)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                18496
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 41,189
# Trainable params: 41,077
# Non-trainable params: 112
# _________________________________________________________________
# None

# %% [markdown]
# Creating the generators

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_exp3_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Fit the model and save the model parameters

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 8
# Epoch 1/25
# 83/83 [==============================] - ETA: 0s - loss: 1.9645 - categorical_accuracy: 0.2428Source path =  /home/datasets/Project_data/val ; batch size = 8
#
# Epoch 00001: val_loss improved from inf to 1.55090, saving model to model_exp3_2021-06-2808_36_21.106173/model-00001-1.96445-0.24284-1.55090-0.25000.h5
# 83/83 [==============================] - 82s 985ms/step - loss: 1.9645 - categorical_accuracy: 0.2428 - val_loss: 1.5509 - val_categorical_accuracy: 0.2500
# Epoch 2/25
# 83/83 [==============================] - ETA: 0s - loss: 1.
# 83/83 [==============================] - 33s 402ms/step - loss: 1.1800 - categorical_accuracy: 0.4779 - val_loss: 0.9266 - val_categorical_accuracy: 0.6731
# Epoch 21/25
# 83/83 [==============================] - ETA: 0s - loss: 1.1833 - categorical_accuracy: 0.4578
# Epoch 00021: val_loss did not improve from 0.92661
# 83/83 [==============================] - 33s 393ms/step - loss: 1.1833 - categorical_accuracy: 0.4578 - val_loss: 1.1562 - val_categorical_accuracy: 0.5000
# Epoch 22/25
# 83/83 [==============================] - ETA: 0s - loss: 1.1915 - categorical_accuracy: 0.4819
# Epoch 00022: val_loss did not improve from 0.92661
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 83/83 [==============================] - 33s 396ms/step - loss: 1.1915 - categorical_accuracy: 0.4819 - val_loss: 0.9723 - val_categorical_accuracy: 0.5962
# Epoch 23/25
# 83/83 [==============================] - ETA: 0s - loss: 1.1610 - categorical_accuracy: 0.4819
# Epoch 00023: val_loss did not improve from 0.92661
# 83/83 [==============================] - 34s 410ms/step - loss: 1.1610 - categorical_accuracy: 0.4819 - val_loss: 1.0648 - val_categorical_accuracy: 0.5192
# Epoch 24/25
# 83/83 [==============================] - ETA: 0s - loss: 1.1817 - categorical_accuracy: 0.4618
# Epoch 00024: val_loss did not improve from 0.92661
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 83/83 [==============================] - 33s 400ms/step - loss: 1.1817 - categorical_accuracy: 0.4618 - val_loss: 1.0056 - val_categorical_accuracy: 0.6346
# Epoch 25/25
# 83/83 [==============================] - ETA: 0s - loss: 1.1027 - categorical_accuracy: 0.4779
# Epoch 00025: val_loss improved from 0.92661 to 0.89797, saving model to model_exp3_2021-06-2808_36_21.106173/model-00025-1.10266-0.47791-0.89797-0.67308.h5
# 83/83 [==============================] - 33s 392ms/step - loss: 1.1027 - categorical_accuracy: 0.4779 - val_loss: 0.8980 - val_categorical_accuracy: 0.6731

# %% [markdown]
# Evaluate the performance of this model

# %%
plot_history(history)
# Out:
# **Training Accuracy:** 0.48%
# **Validation Accuracy:** 0.67%

# %% [markdown]
# <b>Conclusion:</b> Scaling from 50 to 25 reduced the training and validation accuracy

# %% [markdown]
# ### Experiment 4

# %% [markdown]
# Decreasing the batch size from 8 to 4

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4

num_epochs=25

show_resize_crop_image(paths)

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

# %% [markdown]
# Compiling the model and printing the summary of the model

# %%
optimiser = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.7, nesterov=True) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_9 (Conv3D)            (None, 15, 50, 50, 8)     656
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 15, 50, 50, 8)     32
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 50, 50, 8)     0
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 7, 25, 25, 8)      0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 7, 25, 25, 16)     3472
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 25, 25, 16)     64
# _________________________________________________________________
# activation_10 (Activation)   (None, 7, 25, 25, 16)     0
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 3, 12, 12, 16)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 3, 12, 12, 32)     13856
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 3, 12, 12, 32)     128
# _________________________________________________________________
# activation_11 (Activation)   (None, 3, 12, 12, 32)     0
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 1, 6, 6, 32)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                73792
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %% [markdown]
# Creating the generators

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_exp4_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Fit the model and save the model parameters

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 4
# Epoch 1/25
# 166/166 [==============================] - ETA: 0s - loss: 1.7629 - categorical_accuracy: 0.2217Source path =  /home/datasets/Project_data/val ; batch size = 4
#
# Epoch 00001: val_loss improved from inf to 1.58244, saving model to model_exp4_2021-06-2808_36_21.106173/model-00001-1.76295-0.22172-1.58244-0.26000.h5
# 166/166 [==============================] - 80s 480ms/step - loss: 1.7629 - categorical_accuracy: 0.2217 - val_loss: 1.5824 - val_categorical_accuracy: 0.2600
# Epoch 2/25
# 166/166 [==============================] - ETA: 0s - loss: 1.6197 - categorical_accuracy: 0.2249
# Epoch 00002: val_loss did not improve from 1.58244
# 166/166 [==============================] - 63s 382ms/step - loss: 1.6197 - categorical_accuracy: 0.2249 - val_loss: 1.6016 - val_categorical_accuracy: 0.2000
# Epoch 3/25
# 166/166 [==============================] - ETA: 0s - loss: 1.6038 - categorical_accuracy: 0.2349
# Epoch 00003: val_loss did not improve from 1.58244
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 166/166 [==============================] - 66s 397ms/step - loss: 1.6038 - categorical_accuracy: 0.2349 - val_loss: 1.6169 - val_categorical_accuracy: 0.1800
# Epoch 4/25
# 166/166 [==============================] - ETA: 0s - loss: 1.5945 - categorical_accuracy: 0.2289
# Epoch 00004: val_loss improved from 1.58244 to 1.56160, saving model to model_exp4_2021-06-2808_36_21.106173/model-00004-1.59452-0.22892-1.56160-0.27000.h5
# 166/166 [==============================] - 64s 383ms/step - loss: 1.5945 - categorical_accuracy: 0.2289 - val_loss: 1.5616 - val_categorical_accuracy: 0.2700
# Epoch 5/25
# 166/166 [==============================] - ETA: 0s - loss: 1.5801 - categorical_accuracy: 0.2631
# Epoch 00005: val_loss improved from 1.56160 to 1.54081, saving model to model_exp4_2021-06-2808_36_21.106173/model-00005-1.58008-0.26305-1.54081-0.33000.h5
# 166/166 [==============================] - 64s 385ms/step - loss: 1.5801 - categorical_accuracy: 0.2631 - val_loss: 1.5408 - val_categorical_accuracy: 0.3300
# Epoch 6/25
# 166/166 [==============================] - ETA: 0s - loss: 1.5753 - categorical_accuracy: 0.2912
# Epoch 00006: val_loss did not improve from 1.54081
# 166/166 [==============================] - 63s 380ms/step - loss: 1.5753 - categorical_accuracy: 0.2912 - val_loss: 1.5551 - val_categorical_accuracy: 0.3400
# Epoch 7/25
# 166/166 [==============================] - ETA: 0s - loss: 1.
# <b>Conclusion:</b> Reducing the batch size has reduced overfitting

# %% [markdown]
# ### Experiment 5

# %% [markdown]
# Changing the optmizer from `SGD` to `Adam`

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4
num_epochs=25

img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

optimiser = optimizers.Adam(lr=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_12 (Conv3D)           (None, 15, 50, 50, 8)     656
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 15, 50, 50, 8)     32
# _________________________________________________________________
# activation_12 (Activation)   (None, 15, 50, 50, 8)     0
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 7, 25, 25, 8)      0
# _________________________________________________________________
# conv3d_13 (Conv3D)           (None, 7, 25, 25, 16)     3472
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 7, 25, 25, 16)     64
# _________________________________________________________________
# activation_13 (Activation)   (None, 7, 25, 25, 16)     0
# _________________________________________________________________
# max_pooling3d_13 (MaxPooling (None, 3, 12, 12, 16)     0
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 3, 12, 12, 32)     13856
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 3, 12, 12, 32)     128
# _________________________________________________________________
# activation_14 (Activation)   (None, 3, 12, 12, 32)     0
# _________________________________________________________________
# max_pooling3d_14 (MaxPooling (None, 1, 6, 6, 32)       0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                73792
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_exp5_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 4
# Epoch 1/25
# 166/166 [==============================] - ETA: 0s - loss: 1.8307 - categorical_accuracy: 0.2112Source path =  /home/datasets/Project_data/val ; batch size = 4
#
# Epoch 00001: val_loss improved from inf to 1.58582, saving model to model_exp5_2021-06-2808_36_21.106173/model-00001-1.83070-0.21116-1.58582-0.31000.h5
# 166/166 [==============================] - 79s 477ms/step - loss: 1.8307 - categorical_accuracy: 0.2112 - val_loss: 1.5858 - val_categorical_accuracy: 0.3100
# Epoch 2/25
# 166/166 [==============================] - ETA: 0s - loss: 1.6207 - categorical_accuracy: 0.2430
# Epoch 00002: val_loss did not improve from 1.58582
# 166/166 [==============================] - 63s 380ms/step - loss: 1.6207 - categorical_accuracy: 0.2430 - val_loss: 1.5871 - val_categorical_accuracy: 0.3600
# Epoch 3/25
# 166/166 [==============================] - ETA: 0s - loss: 1.5866 - categorical_accuracy: 0.2731
# Epoch 00003: val_loss improved from 1.58582 to 1.54988, saving model to model_exp5_2021-06-2808_36_21.106173/model-00003-1.58657-0.27309-1.54988-0.39000.h5
# 166/166 [==============================] - 63s 379ms/step - loss: 1.5866 - categorical_accuracy: 0.2731 - val_loss: 1.5499 - val_categorical_accuracy: 0.3900
# Epoch 4/25
# 166/166 [==============================] - ETA: 0s - loss: 1.
25
# 166/166 [==============================] - ETA: 0s - loss: 1.2018 - categorical_accuracy: 0.4920
# Epoch 00023: val_loss improved from 0.94748 to 0.93373, saving model to model_exp5_2021-06-2808_36_21.106173/model-00023-1.20183-0.49197-0.93373-0.70000.h5
# 166/166 [==============================] - 65s 390ms/step - loss: 1.2018 - categorical_accuracy: 0.4920 - val_loss: 0.9337 - val_categorical_accuracy: 0.7000
# Epoch 24/25
# 166/166 [==============================] - ETA: 0s - loss: 1.1977 - categorical_accuracy: 0.5000
# Epoch 00024: val_loss did not improve from 0.93373
# 166/166 [==============================] - 64s 387ms/step - loss: 1.1977 - categorical_accuracy: 0.5000 - val_loss: 1.0111 - val_categorical_accuracy: 0.6800
# Epoch 25/25
# 166/166 [==============================] - ETA: 0s - loss: 1.1446 - categorical_accuracy: 0.5382
# Epoch 00025: val_loss improved from 0.93373 to 0.90980, saving model to model_exp5_2021-06-2808_36_21.106173/model-00025-1.14461-0.53815-0.90980-0.71000.h5
# 166/166 [==============================] - 62s 371ms/step - loss: 1.1446 - categorical_accuracy: 0.5382 - val_loss: 0.9098 - val_categorical_accuracy: 0.7100

# %%
plot_history(history)
# Out:
# **Training Accuracy:** 0.54%
# **Validation Accuracy:** 0.71%

# %% [markdown]
# <b>Conclusion:</b> `Adam` has reduced overfitting. However since the accuracy has been constantly improving we might need to increase the number of epochs in a later experiment

# %% [markdown]
# ### Experiment 6

# %% [markdown]
# Reducing the number of frames from 15 to 10

# %%
total_frames = 30
num_frames = 10
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4
num_epochs=25

img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

optimiser = optimizers.Adam(lr=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_15 (Conv3D)           (None, 10, 50, 50, 8)     656
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 10, 50, 50, 8)     32
# _________________________________________________________________
# activation_15 (Activation)   (None, 10, 50, 50, 8)     0
# _________________________________________________________________
# max_pooling3d_15 (MaxPooling (None, 5, 25, 25, 8)      0
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 5, 25, 25, 16)     3472
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 5, 25, 25, 16)     64
# _________________________________________________________________
# activation_16 (Activation)   (None, 5, 25, 25, 16)     0
# _________________________________________________________________
# max_pooling3d_16 (MaxPooling (None, 2, 12, 12, 16)     0
# _________________________________________________________________
# conv3d_17 (Conv3D)           (None, 2, 12, 12, 32)     13856
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 2, 12, 12, 32)     128
# _________________________________________________________________
# activation_17 (Activation)   (None, 2, 12, 12, 32)     0
# _________________________________________________________________
# max_pooling3d_17 (MaxPooling (None, 1, 6, 6, 32)       0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                73792
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 166/166 [==============================] - 45s 272ms/step - loss: 1.2995 - categorical_accuracy: 0.4197 - val_loss: 1.2060 - val_categorical_accuracy: 0.6000
# Epoch 21/25
# 166/166 [==============================] - ETA: 0s - loss: 1.2860 - categorical_accuracy: 0.3936
# Epoch 00021: val_loss did not improve from 1.16094
# 166/166 [==============================] - 43s 260ms/step - loss: 1.2860 - categorical_accuracy: 0.3936 - val_loss: 1.1631 - val_categorical_accuracy: 0.6100
# Epoch 22/25
# 166/166 [==============================] - ETA: 0s - loss: 1.2424 - categorical_accuracy: 0.4458
# Epoch 00022: val_loss did not improve from 1.16094
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 166/166 [==============================] - 45s 270ms/step - loss: 1.2424 - categorical_accuracy: 0.4458 - val_loss: 1.1631 - val_categorical_accuracy: 0.6300
# Epoch 23/25
# 166/166 [==============================] - ETA: 0s - loss: 1.2509 - categorical_accuracy: 0.4679
# Epoch 00023: val_loss improved from 1.16094 to 1.12996, saving model to model_exp6_2021-06-2808_36_21.106173/model-00023-1.25094-0.46787-1.12996-0.64000.h5
# 166/166 [==============================] - 43s 258ms/step - loss: 1.2509 - categorical_accuracy: 0.4679 - val_loss: 1.1300 - val_categorical_accuracy: 0.6400
# Epoch 24/25
# 166/166 [==============================] - ETA: 0s - loss: 1.3037 - categorical_accuracy: 0.4137
# Epoch 00024: val_loss did not improve from 1.12996
# 166/166 [==============================] - 46s 275ms/step - loss: 1.3037 - categorical_accuracy: 0.4137 - val_loss: 1.1617 - val_categorical_accuracy: 0.6400
# Epoch 25/25
# 166/166 [==============================] - ETA: 0s - loss: 1.2671 - categorical_accuracy: 0.4157
# Epoch 00025: val_loss did not improve from 1.12996
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 166/166 [==============================] - 44s 265ms/step - loss: 1.2671 - categorical_accuracy: 0.4157 - val_loss: 1.1675 - val_categorical_accuracy: 0.6100

# %%
plot_history(history)
# Out:
# **Training Accuracy:** 0.42%
# **Validation Accuracy:** 0.61%

# %% [markdown]
# <b>Conclusion:</b> The training and validation accuracy has increased after reducing the number of frames from 15 to 10

# %% [markdown]
# ### Experiment 7

# %% [markdown]
# Reducing the dropout rate from 0.5 to 0.25

# %%
total_frames = 30
num_frames = 10
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4

num_epochs=25

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

optimiser = optimizers.Adam(lr=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_18 (Conv3D)           (None, 10, 50, 50, 8)     656
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 10, 50, 50, 8)     32
# _________________________________________________________________
# activation_18 (Activation)   (None, 10, 50, 50, 8)     0
# _________________________________________________________________
# max_pooling3d_18 (MaxPooling (None, 5, 25, 25, 8)      0
# _________________________________________________________________
# conv3d_19 (Conv3D)           (None, 5, 25, 25, 16)     3472
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 5, 25, 25, 16)     64
# _________________________________________________________________
# activation_19 (Activation)   (None, 5, 25, 25, 16)     0
# _________________________________________________________________
# max_pooling3d_19 (MaxPooling (None, 2, 12, 12, 16)     0
# _________________________________________________________________
# conv3d_20 (Conv3D)           (None, 2, 12, 12, 32)     13856
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 2,
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 166/166 [==============================] - 44s 262ms/step - loss: 0.3553 - categorical_accuracy: 0.8815 - val_loss: 0.6005 - val_categorical_accuracy: 0.7800
# Epoch 24/25
# 166/166 [==============================] - ETA: 0s - loss: 0.3139 - categorical_accuracy: 0.9116
# Epoch 00024: val_loss did not improve from 0.52336
# 166/166 [==============================] - 44s 263ms/step - loss: 0.3139 - categorical_accuracy: 0.9116 - val_loss: 0.5397 - val_categorical_accuracy: 0.8100
# Epoch 25/25
# 166/166 [==============================] - ETA: 0s - loss: 0.3135 - categorical_accuracy: 0.8956
# Epoch 00025: val_loss did not improve from 0.52336
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 166/166 [==============================] - 45s 272ms/step - loss: 0.3135 - categorical_accuracy: 0.8956 - val_loss: 0.5807 - val_categorical_accuracy: 0.8000

# %%
plot_history(history)
# Out:
# **Training Accuracy:** 0.9%
# **Validation Accuracy:** 0.8%

# %% [markdown]
# <b>Conclusion:</b> A drop out rate of 0.25 gives up a better training and validation accuracy

# %% [markdown]
# ### Experiment 8

# %% [markdown]
# Increasing the number of epochs from 25 to 35

# %%
total_frames = 30
num_frames = 10
gestures = 5
image_height = 50
image_width = 50
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)
batch_size = 4

num_epochs=35

# %%
#write your model here
model = Sequential()

model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=(len(img_idx), image_height, image_width, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

#softmax layer
model.add(Dense(gestures, activation='softmax'))

optimiser = optimizers.Adam(lr=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_21 (Conv3D)           (None, 10, 50, 50, 8)     656
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 10, 50, 50, 8)     32
# _________________________________________________________________
# activation_21 (Activation)   (None, 10, 50, 50, 8)     0
# _________________________________________________________________
# max_pooling3d_21 (MaxPooling (None, 5, 25, 25, 8)      0
# _________________________________________________________________
# conv3d_22 (Conv3D)           (None, 5, 25, 25, 16)     3472
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 5, 25, 25, 16)     64
# _________________________________________________________________
# activation_22 (Activation)   (None, 5, 25, 25, 16)     0
# _________________________________________________________________
# max_pooling3d_22 (MaxPooling (None, 2, 12, 12, 16)     0
# _________________________________________________________________
# conv3d_23 (Conv3D)           (None, 2, 12, 12, 32)     13856
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 2, 12, 12, 32)     128
# _________________________________________________________________
# activation_23 (Activation)   (None, 2, 12, 12, 32)     0
# _________________________________________________________________
# max_pooling3d_23 (MaxPooling (None, 1, 6, 6, 32)       0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                73792
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 96,485
# Trainable params: 96,373
# Non-trainable params: 112
# _________________________________________________________________
# None

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_exp8_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 4
# Epoch 1/35
# 166/166 [==============================] - ETA: 0s - loss: 1.7059 - categorical_accuracy: 0.2021Source path =  /home/datasets/Project_data/val ; batch size = 4
#
# Epoch 00001: val_loss improved from inf to 1.54653, saving model to model_exp8_2021-06-2808_36_21.106173/model-00001-1.70590-0.20211-1.54653-0.32000.h5
# 166/166 [==============================] - 55s 331ms/step - loss: 1.7059 - categorical_accuracy: 0.2021 - val_loss: 1.5465 - val_categorical_accuracy: 0.3200
# Epoch 2/35
# 166/166 [==============================] - ETA: 0s - loss: 1.5649 - categorical_accuracy: 0.2731
# Epoch 00002: val_loss improved from 1.54653 to 1.30555, saving model to model_exp8_2021-06-2808_36_21.106173/model-00002-1.56489-0.27309-1.30555-0.54000.h5
